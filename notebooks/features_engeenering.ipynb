# %% [markdown]
# # Features engineering

# %%
# Libraries and parameters
import pandas as pd
pd.set_option('display.max_columns', None)

# Functions
from functions import haversine

# %%
# Import data
data = pd.read_csv("../raw_data/data_merged.csv")
data.head(2)
# Out:
# /var/folders/hn/9bq5pp413ql4k7q7btsvrkkw0000gn/T/ipykernel_25359/1150491627.py:2: DtypeWarning: Columns (31,66,81) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../raw_data/data_merged.csv")
#    Unnamed: 0                                    id  \
# 0           0  e7acb70b-affd-4fe8-9dcb-8a71da23612b
# 1           1  e7acb70b-affd-4fe8-9dcb-8a71da23612b
#
#                                 game_id  inning side  \
# 0  00846785-f968-4867-8896-cb4d5f7a3e63       1    T
# 1  00846785-f968-4867-8896-cb4d5f7a3e63       1    T
#
#                               hitter_id hitter_hand  \
# 0  6ea2efc3-345a-4e30-8b95-744a60a3e7a5           R
# 1  6ea2efc3-345a-4e30-8b95-744a60a3e7a5           R
#
#                              pitcher_id pitcher_hand  \
# 0  738eb5e8-2ab8-4428-928a-81a31b7228de            R
# 1  738eb5e8-2ab8-4428-928a-81a31b7228de            R
#
#                                          description  temp_f  \
# 0  Nico Hoerner flies out to left field to Luis R...    70.0
# 1  Nico Hoerner flies out to left field to Luis R...    70.0
#
#   weather_condition  humidity  wind_speed_mph  y_target  status coverage  \
# 0     Partly cloudy      53.0             4.0         0  closed     full
# 1     Partly cloudy      53.0             4.0         0  closed     full
#
#    game_number day_night                  scheduled  \
# 0            1         N  2023-06-08T01:38:00+00:00
# 1            1         N  2023-06-08T01:38:00+00:00
#
#                            home_team_id                          away_team_id  \
# 0  4f735188-37c8-473d-ae32-1f7e34ccf892  55714da8-fcaf-4574-8443-59bfb511a524
# 1  4f735188-37c8-473d-ae32-1f7e34ccf892  55714da8-fcaf-4574-8443-59bfb511a524
#
#    attendance duration  double_header entry_mode  reference  \
# 0     28817.0     2:31          False      STOMP     717855
# 1     28817.0     2:31          False      STOMP     717855
#
#                                                venue  \
# 0  {'name': 'Angel Stadium', 'market': 'Los Angel...
# 1  {'name': 'Angel Stadium', 'market': 'Los Angel...
#
#                                                 home  \
# 0  {'name': 'Angels', 'market': 'Los Angeles', 'a...
# 1  {'name': 'Angels', 'market': 'Los Angeles', 'a...
#
#                                                 away  \
# 0  {'name': 'Cubs', 'market': 'Chicago', 'abbr': ...
# 1  {'name': 'Cubs', 'market': 'Chicago', 'abbr': ...
#
#                     broadcast rescheduled  \
# 0  {'network': 'MLB Network'}         NaN
# 1  {'network': 'MLB Network'}         NaN
#
#                              stadium_id hitter_status hitter_position  \
# 0  60732da9-ad03-4feb-9a36-aee3e98c7a2b             A              IF
# 1  60732da9-ad03-4feb-9a36-aee3e98c7a2b             A              IF
#
#   hitter_primary_position hitter_first_name hitter_last_name  \
# 0                      2B          Nicholas          Hoerner
# 1                      2B          Nicholas          Hoerner
#
#   hitter_preferred_name  hitter_jersey_number  hitter_depth  \
# 0                  Nico                   2.0           2.0
# 1                  Nico                   2.0           1.0
#
#                          hitter_team_id hitter_team_nickname pitcher_status  \
# 0  55714da8-fcaf-4574-8443-59bfb511a524                 Cubs              A
# 1  55714da8-fcaf-4574-8443-59bfb511a524                 Cubs              A
#
#   pitcher_position pitcher_primary_position pitcher_first_name  \
# 0                P                       RP              Jaime
# 1                P                       RP              Jaime
#
#   pitcher_last_name pitcher_preferred_name  pitcher_jersey_number  \
# 0            Barría                  Jaime                   51.0
# 1            Barría                  Jaime                   51.0
#
#    pitcher_depth                       pitcher_team_id pitcher_team_nickname  \
# 0            6.0  4f735188-37c8-473d-ae32-1f7e34ccf892                Angels
# 1            6.0  4f735188-37c8-473d-ae32-1f7e34ccf892                Angels
#
#   home_team_name home_team_market home_team_abbr away_team_name  \
# 0         Angels      Los Angeles            LAA           Cubs
# 1         Angels      Los Angeles            LAA           Cubs
#
#   away_team_market away_team_abbr   stadium_name stadium_market  \
# 0          Chicago            CHC  Angel Stadium    Los Angeles
# 1          Chicago            CHC  Angel Stadium    Los Angeles
#
#    stadium_capacity stadium_surface      stadium_address stadium_city  \
# 0           45517.0           grass  2000 Gene Autry Way      Anaheim
# 1           45517.0           grass  2000 Gene Autry Way      Anaheim
#
#   stadium_state stadium_zip stadium_country stadium_field_orientation  \
# 0            CA     92806.0             USA                        NE
# 1            CA     92806.0             USA                        NE
#
#   stadium_stadium_type stadium_time_zone  stadium_lat  stadium_lon  \
# 0              outdoor        US/Pacific    33.799662  -117.883438
# 1              outdoor        US/Pacific    33.799662  -117.883438
#
#                         away_stadium_id away_stadium_name away_stadium_market  \
# 0  53f8eb0d-a361-4a7a-930b-2f8735ea0698     Wrigley Field             Chicago
# 1  53f8eb0d-a361-4a7a-930b-2f8735ea0698     Wrigley Field             Chicago
#
#    away_stadium_capacity away_stadium_surface      away_stadium_address  \
# 0                41363.0                grass  1060 West Addison Street
# 1                41363.0                grass  1060 West Addison Street
#
#   away_stadium_city away_stadium_state away_stadium_zip away_stadium_country  \
# 0           Chicago                 IL            60613                  USA
# 1           Chicago                 IL            60613                  USA
#
#   away_stadium_field_orientation away_stadium_stadium_type  \
# 0                             NE                   outdoor
# 1                             NE                   outdoor
#
#   away_stadium_time_zone  away_stadium_lat  away_stadium_lon
# 0             US/Central         41.947447        -87.656054
# 1             US/Central         41.947447        -87.656054

# %%
# Calculate distance between home and away team
data["distance"] = data.apply(lambda row: haversine(row["stadium_lat"], row["stadium_lon"], row["away_stadium_lat"], row["away_stadium_lon"]), axis=1)
data.head(2)
# Out:
#    Unnamed: 0                                    id  \
# 0           0  e7acb70b-affd-4fe8-9dcb-8a71da23612b
# 1           1  e7acb70b-affd-4fe8-9dcb-8a71da23612b
#
#                                 game_id  inning side  \
# 0  00846785-f968-4867-8896-cb4d5f7a3e63       1    T
# 1  00846785-f968-4867-8896-cb4d5f7a3e63       1    T
#
#                               hitter_id hitter_hand  \
# 0  6ea2efc3-345a-4e30-8b95-744a60a3e7a5           R
# 1  6ea2efc3-345a-4e30-8b95-744a60a3e7a5           R
#
#                              pitcher_id pitcher_hand  \
# 0  738eb5e8-2ab8-4428-928a-81a31b7228de            R
# 1  738eb5e8-2ab8-4428-928a-81a31b7228de            R
#
#                                          description  temp_f  \
# 0  Nico Hoerner flies out to left field to Luis R...    70.0
# 1  Nico Hoerner flies out to left field to Luis R...    70.0
#
#   weather_condition  humidity  wind_speed_mph  y_target  status coverage  \
# 0     Partly cloudy      53.0             4.0         0  closed     full
# 1     Partly cloudy      53.0             4.0         0  closed     full
#
#    game_number day_night                  scheduled  \
# 0            1         N  2023-06-08T01:38:00+00:00
# 1            1         N  2023-06-08T01:38:00+00:00
#
#                            home_team_id                          away_team_id  \
# 0  4f735188-37c8-473d-ae32-1f7e34ccf892  55714da8-fcaf-4574-8443-59bfb511a524
# 1  4f735188-37c8-473d-ae32-1f7e34ccf892  55714da8-fcaf-4574-8443-59bfb511a524
#
#    attendance duration  double_header entry_mode  reference  \
# 0     28817.0     2:31          False      STOMP     717855
# 1     28817.0     2:31          False      STOMP     717855
#
#                                                venue  \
# 0  {'name': 'Angel Stadium', 'market': 'Los Angel...
# 1  {'name': 'Angel Stadium', 'market': 'Los Angel...
#
#                                                 home  \
# 0  {'name': 'Angels', 'market': 'Los Angeles', 'a...
# 1  {'name': 'Angels', 'market': 'Los Angeles', 'a...
#
#                                                 away  \
# 0  {'name': 'Cubs', 'market': 'Chicago', 'abbr': ...
# 1  {'name': 'Cubs', 'market': 'Chicago', 'abbr': ...
#
#                     broadcast rescheduled  \
# 0  {'network': 'MLB Network'}         NaN
# 1  {'network': 'MLB Network'}         NaN
#
#                              stadium_id hitter_status hitter_position  \
# 0  60732da9-ad03-4feb-9a36-aee3e98c7a2b             A              IF
# 1  60732da9-ad03-4feb-9a36-aee3e98c7a2b             A              IF
#
#   hitter_primary_position hitter_first_name hitter_last_name  \
# 0                      2B          Nicholas          Hoerner
# 1                      2B          Nicholas          Hoerner
#
#   hitter_preferred_name  hitter_jersey_number  hitter_depth  \
# 0                  Nico                   2.0           2.0
# 1                  Nico                   2.0           1.0
#
#                          hitter_team_id hitter_team_nickname pitcher_status  \
# 0  55714da8-fcaf-4574-8443-59bfb511a524                 Cubs              A
# 1  55714da8-fcaf-4574-8443-59bfb511a524                 Cubs              A
#
#   pitcher_position pitcher_primary_position pitcher_first_name  \
# 0                P                       RP              Jaime
# 1                P                       RP              Jaime
#
#   pitcher_last_name pitcher_preferred_name  pitcher_jersey_number  \
# 0            Barría                  Jaime                   51.0
# 1            Barría                  Jaime                   51.0
#
#    pitcher_depth                       pitcher_team_id pitcher_team_nickname  \
# 0            6.0  4f735188-37c8-473d-ae32-1f7e34ccf892                Angels
# 1            6.0  4f735188-37c8-473d-ae32-1f7e34ccf892                Angels
#
#   home_team_name home_team_market home_team_abbr away_team_name  \
# 0         Angels      Los Angeles            LAA           Cubs
# 1         Angels      Los Angeles            LAA           Cubs
#
#   away_team_market away_team_abbr   stadium_name stadium_market  \
# 0          Chicago            CHC  Angel Stadium    Los Angeles
# 1          Chicago            CHC  Angel Stadium    Los Angeles
#
#    stadium_capacity stadium_surface      stadium_address stadium_city  \
# 0           45517.0           grass  2000 Gene Autry Way      Anaheim
# 1           45517.0           grass  2000 Gene Autry Way      Anaheim
#
#   stadium_state stadium_zip stadium_country stadium_field_orientation  \
# 0            CA     92806.0             USA                        NE
# 1            CA     92806.0             USA                        NE
#
#   stadium_stadium_type stadium_time_zone  stadium_lat  stadium_lon  \
# 0              outdoor        US/Pacific    33.799662  -117.883438
# 1              outdoor        US/Pacific    33.799662  -117.883438
#
#                         away_stadium_id away_stadium_name away_stadium_market  \
# 0  53f8eb0d-a361-4a7a-930b-2f8735ea0698     Wrigley Field             Chicago
# 1  53f8eb0d-a361-4a7a-930b-2f8735ea0698     Wrigley Field             Chicago
#
#    away_stadium_capacity away_stadium_surface      away_stadium_address  \
# 0                41363.0                grass  1060 West Addison Street
# 1                41363.0                grass  1060 West Addison Street
#
#   away_stadium_city away_stadium_state away_stadium_zip away_stadium_country  \
# 0           Chicago                 IL            60613                  USA
# 1           Chicago                 IL            60613                  USA
#
#   away_stadium_field_orientation away_stadium_stadium_type  \
# 0                             NE                   outdoor
# 1                             NE                   outdoor
#
#   away_stadium_time_zone  away_stadium_lat  away_stadium_lon     distance
# 0             US/Central         41.947447        -87.656054  2786.440777
# 1             US/Central         41.947447        -87.656054  2786.440777

# %%
# Out:
# Unnamed: 0                     int64
# id                            object
# game_id                       object
# inning                         int64
# side                          object
#                               ...
# away_stadium_stadium_type     object
# away_stadium_time_zone        object
# away_stadium_lat             float64
# away_stadium_lon             float64
# distance                     float64
# Length: 89, dtype: object
